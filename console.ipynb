// %% [markdown]
// ## Вход на Everest
//
// Для запуска Вашей программы *program.cpp* (см. **File Browser**, **Ctrl+Shift+F**) на кластере [Сергей Королев](http://hpc.ssau.ru/) используется платформа [Everest](https://everest.distcomp.org). Поэтому перед началом работы Вы должны войти в учетную запись *SSAUstudent* на платформе *Everest*. Для входа в учетную запись выделите ячейку под данной ячейкой. Затем зажмите кнопку **[>]** (**Run the selected sells and advance**) на панели инструментов консоли. Введите логин и пароль. Также ячейку можно выполнить, нажав сочетание клавиш (**Shift+Enter**) или выбрав в главном меню *JupyterLab* раздел **Ru|Run Selected Sells**.
//
// > Далее приведены другие ячееки, содержащие операции обработки кода Вашей программы. Они запускаются таким же способом.

// %% [markdown]
// ## Компиляция на узле Binder
//
// Запустите ячейку под этой ячейкой для компиляции кода Вашей программы на узле системы [Binder](https://mybinder.org/). Это быстрый способ проверить синтаксическую корректность Вашего кода.

// %% [markdown]
// ## Запуск на узле Binder
//
// Запустите ячейку под этой ячейкой для исполнения кода Вашей программы на узле системы *Binder*. Это быстрый способ проверить работоспособность Вашей программы.
//
// > Учтите, что вычислительный узел системы *Binder* не предназначен для ресурсоемких расчетов. На данном узле Вам отводится необходимый для демонстрационных целей минимум вычислительных ресурсов.

// %% [markdown]
// ## Компиляция на кластере *Сергей Королев*
//
// Запустите ячейку под этой ячейкой для компиляции кода Вашей программы на управляющем узле кластера *Сергей Королев*.
//
// > На узлах *Binder* и управляющем узле кластера *Сергей Королев* установлены разные версии компилятора и отличаются настройки окружения. Поэтому рекомендуется убедиться в отсутсвии ошибок компиляции на кластере *Сергей Королев* даже при отсутсвии ошибок компиляции на узле *Binder*.

// %% [markdown]
// ## Запуск на кластере *Сергей Королев*
//
// Запустите ячейку под этой ячейкой для исполнения кода Вашей программы на кластере *Сергей Королев*.
//
// > Запущенная таким образом программа, если она не содержит ошибок, попадает в очеред планировщика SLURM кластера *Сергей Королев*. Состояние её хода выполения нужно периодически опрашивать, запуская следующую далее ячейку с кодом.

// %% [markdown]
// ## Проверка состояния задачи на кластере *Сергей Королев*
//
// Запустите ячейку под этой ячейкой для проверки состояния Вашей программы на кластере *Сергей Королев*.
//
// > Ваша программа будет исполняться на кластере *Сергей Королев* **не более 5 минут**. Но перед этим она может ожидать в очереди планировщика, если нет доступых для её запуска узлов на кластере. Исходя из этого, выбирайте период опроса состояния Вашей задачи.

// %% [markdown]
// ## Выход из *Everest*
//
// После завершения работы ***не забудьте*** выйти из учетной записи платформы *Everest*, выполнив ячейку под этой ячейкой.

// %% [markdown]
// ## Советы по предотвращению потери данных
//
// Серверная часть этого приложения работает в ненадежном окружении *Binder*. Поэтому следует выполнять процедуры, описанные ниже, чтобы избежать потери данных при разрыве связи между интерфейсной частью приложения в Вашем браузере и виртуальной машиной в облаке; либо при разрыве связи с ядром, управляющим вычислением ячеек ноутбука.
//
// > **Совет 1.** Периодически загружайте на локальную машину файл *'program.cpp'*. Для загрузки используйте команды главного меню **File|Download** или контексного меню **Download**. Файл *'program.cpp'*  должен подсвечиваться в **File Browser**.
//
// > **Совет 2.** Всегда держите открытой вкладку редактора с содержимым файла *'program.cpp'*. Даже при потере связи с виртуальной машиной сервера приложения в облаке, содержимое файла можно будет скопировать и сохранить. Для этого нужно выделить текст программы и выполнить команду **Ctrl+C**, затем **Ctrl+V** в тектовом редакторе на локальной машине.
//
// > **Совет 3.** При потери связи с ядром его можно перезапустить командой **Kernel|Restart Kernel...** в главном меню или соответсвующей кнопкой на панели инструментов. Код ячеек написан таким образом, что состояние приложения сохраняется в файловой системе на виртуальной машине в облаке. После перезапуска ядра можно выполнить повторный запуск ячейки.
//
// > **Совет 4.** Если отказ на виртуальной машине в облаке произошел после запуска задачи на кластере *Сергей Королев*, после перезапуска приложения можно продолжить проверку состояния этой задачи. Для этого запомните номер задачи, выданный при её запуске. После перезапуска создайте вручную файл *'sys/taskID.txt'* и поместите в него этот номер. После входа на платформу *Everest* можно сразу выполнить ячейку проверки состояния задачи.
